# /kaggle/input/flowers/flower_data/valid/52/image_04163.jpg
# /kaggle/input/flowers/flower_data/valid/52/image_04207.jpg
# /kaggle/input/flowers/flower_data/valid/52/image_04173.jpg
# /kaggle/input/flowers/flower_data/valid/52/image_04235.jpg
# /kaggle/input/flowers/flower_data/valid/52/image_04191.jpg
# /kaggle/input/flowers/flower_data/valid/52/image_04225.jpg
# /kaggle/input/flowers/flower_data/valid/52/image_04182.jpg
# /kaggle/input/flowers/flower_data/valid/52/image_04172.jpg
# /kaggle/input/flowers/flower_data/valid/75/image_02130.jpg
# /kaggle/input/flowers/flower_data/valid/75/image_02147.jpg
# /kaggle/input/flowers/flower_data/valid/75/image_02141.jpg
# /kaggle/input/flowers/flower_data/valid/75/image_02155.jpg
# /kaggle/input/flowers/flower_data/valid/75/image_02081.jpg
# /kaggle/input/flowers/flower_data/valid/75/image_02074.jpg
# /kaggle/input/flowers/flower_data/valid/75/image_02133.jpg
# /kaggle/input/flowers/flower_data/valid/75/image_02100.jpg
# /kaggle/input/flowers/flower_data/valid/75/image_02178.jpg
# /kaggle/input/flowers/flower_data/valid/75/image_02152.jpg
# /kaggle/input/flowers/flower_data/valid/75/image_02104.jpg
# /kaggle/input/flowers/flower_data/valid/75/image_02182.jpg
# /kaggle/input/flowers/flower_data/valid/8/image_03313.jpg
# /kaggle/input/flowers/flower_data/valid/8/image_03366.jpg
# /kaggle/input/flowers/flower_data/valid/8/image_03342.jpg
# /kaggle/input/flowers/flower_data/valid/8/image_03349.jpg
# /kaggle/input/flowers/flower_data/valid/8/image_03330.jpg
# /kaggle/input/flowers/flower_data/valid/38/image_05829.jpg
# /kaggle/input/flowers/flower_data/valid/38/image_05830.jpg
# /kaggle/input/flowers/flower_data/valid/38/image_05819.jpg
# /kaggle/input/flowers/flower_data/valid/38/image_05845.jpg
# /kaggle/input/flowers/flower_data/valid/12/image_04080.jpg
# /kaggle/input/flowers/flower_data/valid/12/image_04013.jpg
# /kaggle/input/flowers/flower_data/valid/12/image_04072.jpg
# /kaggle/input/flowers/flower_data/valid/12/image_03998.jpg
# /kaggle/input/flowers/flower_data/valid/12/image_03997.jpg
# /kaggle/input/flowers/flower_data/valid/94/image_07317.jpg
# /kaggle/input/flowers/flower_data/valid/94/image_07385.jpg
# /kaggle/input/flowers/flower_data/valid/94/image_07449.jpg
# /kaggle/input/flowers/flower_data/valid/94/image_07360.jpg
# /kaggle/input/flowers/flower_data/valid/94/image_07381.jpg
# /kaggle/input/flowers/flower_data/valid/94/image_07382.jpg
# /kaggle/input/flowers/flower_data/valid/94/image_07435.jpg
# /kaggle/input/flowers/flower_data/valid/94/image_07393.jpg
# /kaggle/input/flowers/flower_data/valid/94/image_07392.jpg
# /kaggle/input/flowers/flower_data/valid/94/image_07325.jpg
# /kaggle/input/flowers/flower_data/valid/94/image_07372.jpg
# /kaggle/input/flowers/flower_data/valid/94/image_07408.jpg
# /kaggle/input/flowers/flower_data/valid/94/image_07418.jpg
jpg
# /kaggle/input/flowers/flower_data/valid/46/image_01095.jpg
# /kaggle/input/flowers/flower_data/valid/46/image_01050.jpg
# /kaggle/input/flowers/flower_data/valid/46/image_01076.jpg
# /kaggle/input/flowers/flower_data/valid/46/image_01047.jpg
# /kaggle/input/flowers/flower_data/valid/46/image_01034.jpg
# /kaggle/input/flowers/flower_data/valid/46/image_00977.jpg
# /kaggle/input/flowers/flower_data/valid/46/image_01100.jpg
# /kaggle/input/flowers/flower_data/valid/46/image_01040.jpg
# /kaggle/input/flowers/flower_data/valid/46/image_01142.jpg
# /kaggle/input/flowers/flower_data/valid/46/image_01086.jpg
# /kaggle/input/flowers/flower_data/valid/46/image_01129.jpg
# /kaggle/input/flowers/flower_data/valid/46/image_01030.jpg
# /kaggle/input/flowers/flower_data/valid/46/image_01132.jpg
# /kaggle/input/flowers/flower_data/valid/46/image_00949.jpg
# /kaggle/input/flowers/flower_data/valid/46/image_00983.jpg
# /kaggle/input/flowers/flower_data/valid/46/image_01029.jpg
# /kaggle/input/flowers/flower_data/valid/46/image_01065.jpg
# /kaggle/input/flowers/flower_data/valid/46/image_01138.jpg
# /kaggle/input/flowers/flower_data/valid/21/image_06804.jpg
# /kaggle/input/flowers/flower_data/valid/21/image_06784.jpg
# /kaggle/input/flowers/flower_data/valid/21/image_06778.jpg
# /kaggle/input/flowers/flower_data/valid/21/image_06788.jpg
# /kaggle/input/flowers/flower_data/valid/44/image_01573.jpg
# /kaggle/input/flowers/flower_data/valid/44/image_01510.jpg
# /kaggle/input/flowers/flower_data/valid/44/image_01491.jpg
# /kaggle/input/flowers/flower_data/valid/44/image_01540.jpg
# /kaggle/input/flowers/flower_data/valid/44/image_01570.jpg
# /kaggle/input/flowers/flower_data/valid/44/image_01569.jpg
# /kaggle/input/flowers/flower_data/valid/44/image_01579.jpg
# /kaggle/input/flowers/flower_data/valid/44/image_01500.jpg
# /kaggle/input/flowers/flower_data/valid/44/image_01494.jpg
# /kaggle/input/flowers/flower_data/valid/40/image_04584.jpg
# /kaggle/input/flowers/flower_data/valid/40/image_04608.jpg
# /kaggle/input/flowers/flower_data/valid/40/image_04596.jpg
# /kaggle/input/flowers/flower_data/valid/40/image_04579.jpg
# /kaggle/input/flowers/flower_data/valid/40/image_04578.jpg
# /kaggle/input/flowers/flower_data/valid/80/image_01992.jpg
# /kaggle/input/flowers/flower_data/valid/80/image_02050.jpg
# /kaggle/input/flowers/flower_data/valid/80/image_02042.jpg
# /kaggle/input/flowers/flower_data/valid/80/image_01975.jpg
# /kaggle/input/flowers/flower_data/valid/80/image_02011.jpg
# /kaggle/input/flowers/flower_data/valid/80/image_02005.jpg
# /kaggle/input/flowers/flower_data/valid/80/image_01989.jpg
# /kaggle/input/flowers/flower_data/valid/80/image_02017.jpg
# /kaggle/input/flowers/flower_data/valid/80/image_01979.jpg
# /kaggle/input/flowers/flower_data/valid/80/image_01991.jpg
# /kaggle/input/flowers/flower_data/valid/80/image_02021.jpg
# /kaggle/input/flowers/flower_data/valid/80/image_01972.jpg
# /kaggle/input/flowers/flower_data/valid/6/image_08105.jpg
# /kaggle/input/flowers/flower_data/valid/11/image_03145.jpg
# /kaggle/input/flowers/flower_data/valid/11/image_03139.jpg
# /kaggle/input/flowers/flower_data/valid/11/image_03157.jpg
# /kaggle/input/flowers/flower_data/valid/11/image_03128.jpg
# /kaggle/input/flowers/flower_data/valid/11/image_03125.jpg
# /kaggle/input/flowers/flower_data/valid/11/image_03100.jpg
# /kaggle/input/flowers/flower_data/valid/11/image_03111.jpg
# /kaggle/input/flowers/flower_data/valid/11/image_03116.jpg
# /kaggle/input/flowers/flower_data/valid/11/image_03173.jpg
# /kaggle/input/flowers/flower_data/valid/11/image_03108.jpg
# /kaggle/input/flowers/flower_data/valid/68/image_05904.jpg
# /kaggle/input/flowers/flower_data/valid/68/image_05908.jpg
# /kaggle/input/flowers/flower_data/valid/68/image_05924.jpg
# /kaggle/input/flowers/flower_data/valid/68/image_05926.jpg
# /kaggle/input/flowers/flower_data/valid/68/image_05932.jpg
# /kaggle/input/flowers/flower_data/valid/68/image_05915.jpg
# /kaggle/input/flowers/flower_data/valid/68/image_05916.jpg
# /kaggle/input/flowers/flower_data/valid/68/image_05919.jpg
# /kaggle/input/flowers/flower_data/valid/63/image_05894.jpg
# /kaggle/input/flowers/flower_data/valid/63/image_05876.jpg
# /kaggle/input/flowers/flower_data/valid/63/image_05871.jpg
# /kaggle/input/flowers/flower_data/valid/63/image_05853.jpg
# /kaggle/input/flowers/flower_data/valid/63/image_05861.jpg
# /kaggle/input/flowers/flower_data/valid/63/image_05898.jpg
# /kaggle/input/flowers/flower_data/valid/63/image_05867.jpg
# /kaggle/input/flowers/flower_data/valid/63/image_05857.jpg
# /kaggle/input/flowers/flower_data/valid/37/image_03765.jpg
# /kaggle/input/flowers/flower_data/valid/37/image_03756.jpg
# /kaggle/input/flowers/flower_data/valid/37/image_03813.jpg
# /kaggle/input/flowers/flower_data/valid/37/image_03768.jpg
# /kaggle/input/flowers/flower_data/valid/37/image_03820.jpg
# /kaggle/input/flowers/flower_data/valid/37/image_03822.jpg
# /kaggle/input/flowers/flower_data/valid/37/image_03785.jpg
# /kaggle/input/flowers/flower_data/valid/37/image_03810.jpg
# /kaggle/input/flowers/flower_data/valid/51/image_03917.jpg
# /kaggle/input/flowers/flower_data/valid/51/image_03938.jpg
# /kaggle/input/flowers/flower_data/valid/51/image_01352.jpg
# /kaggle/input/flowers/flower_data/valid/51/image_01459.jpg
# /kaggle/input/flowers/flower_data/valid/51/image_01473.jpg
# /kaggle/input/flowers/flower_data/valid/51/image_03943.jpg
# /kaggle/input/flowers/flower_data/valid/51/image_01326.jpg
# /kaggle/input/flowers/flower_data/valid/51/image_01354.jpg
# /kaggle/input/flowers/flower_data/valid/51/image_03916.jpg
# /kaggle/input/flowers/flower_data/valid/51/image_03951.jpg
# /kaggle/input/flowers/flower_data/valid/51/image_03937.jpg
# /kaggle/input/flowers/flower_data/valid/51/image_03974.jpg
# /kaggle/input/flowers/flower_data/valid/51/image_01363.jpg
# /kaggle/input/flowers/flower_data/valid/51/image_01425.jpg
# /kaggle/input/flowers/flower_data/valid/51/image_03927.jpg
# /kaggle/input/flowers/flower_data/valid/51/image_01439.jpg
# /kaggle/input/flowers/flower_data/valid/51/image_01469.jpg
# /kaggle/input/flowers/flower_data/valid/51/image_01346.jpg
# /kaggle/input/flowers/flower_data/valid/51/image_01414.jpg
# /kaggle/input/flowers/flower_data/valid/51/image_01389.jpg
# /kaggle/input/flowers/flower_data/valid/51/image_03946.jpg
# /kaggle/input/flowers/flower_data/valid/51/image_01322.jpg
# /kaggle/input/flowers/flower_data/valid/51/image_03975.jpg
# /kaggle/input/flowers/flower_data/valid/51/image_01419.jpg
# /kaggle/input/flowers/flower_data/valid/51/image_01391.jpg
# /kaggle/input/flowers/flower_data/valid/51/image_01315.jpg
# /kaggle/input/flowers/flower_data/valid/51/image_03961.jpg
# /kaggle/input/flowers/flower_data/valid/51/image_03933.jpg
# /kaggle/input/flowers/flower_data/valid/33/image_06468.jpg
# /kaggle/input/flowers/flower_data/valid/33/image_06455.jpg
# /kaggle/input/flowers/flower_data/valid/33/image_06444.jpg
# /kaggle/input/flowers/flower_data/valid/33/image_06443.jpg
# /kaggle/input/flowers/flower_data/valid/33/image_06441.jpg
# /kaggle/input/flowers/flower_data/valid/33/image_06481.jpg
# /kaggle/input/flowers/flower_data/valid/33/image_06485.jpg
# /kaggle/input/flowers/flower_data/valid/100/image_07917.jpg
# /kaggle/input/flowers/flower_data/valid/100/image_07895.jpg
# /kaggle/input/flowers/flower_data/valid/100/image_07905.jpg
# /kaggle/input/flowers/flower_data/valid/100/image_07929.jpg
# /kaggle/input/flowers/flower_data/valid/100/image_07931.jpg
# /kaggle/input/flowers/flower_data/valid/100/image_07904.jpg
# /kaggle/input/flowers/flower_data/valid/54/image_05451.jpg
# /kaggle/input/flowers/flower_data/valid/54/image_05417.jpg
# /kaggle/input/flowers/flower_data/valid/54/image_05449.jpg
# /kaggle/input/flowers/flower_data/valid/54/image_05452.jpg
# /kaggle/input/flowers/flower_data/valid/54/image_05453.jpg
# /kaggle/input/flowers/flower_data/valid/54/image_05426.jpg
# /kaggle/input/flowers/flower_data/valid/54/image_05406.jpg
# /kaggle/input/flowers/flower_data/valid/54/image_05411.jpg
# /kaggle/input/flowers/flower_data/valid/54/image_05425.jpg
# /kaggle/input/flowers/flower_data/valid/54/image_05415.jpg
# /kaggle/input/flowers/flower_data/valid/48/image_04691.jpg
# /kaggle/input/flowers/flower_data/valid/48/image_04688.jpg
# /kaggle/input/flowers/flower_data/valid/48/image_04678.jpg
# /kaggle/input/flowers/flower_data/valid/48/image_04693.jpg
# /kaggle/input/flowers/flower_data/valid/48/image_04652.jpg
# /kaggle/input/flowers/flower_data/valid/48/image_04690.jpg
# /kaggle/input/flowers/flower_data/valid/48/image_04687.jpg
# /kaggle/input/flowers/flower_data/valid/48/image_04641.jpg
# /kaggle/input/flowers/flower_data/valid/48/image_04684.jpg
# /kaggle/input/flowers/flower_data/valid/29/image_04099.jpg
# /kaggle/input/flowers/flower_data/valid/29/image_04097.jpg
# /kaggle/input/flowers/flower_data/valid/29/image_04104.jpg
# /kaggle/input/flowers/flower_data/valid/29/image_04108.jpg
# /kaggle/input/flowers/flower_data/valid/29/image_04103.jpg
# /kaggle/input/flowers/flower_data/valid/29/image_04143.jpg
# /kaggle/input/flowers/flower_data/valid/29/image_04116.jpg
# /kaggle/input/flowers/flower_data/valid/24/image_06818.jpg
# /kaggle/input/flowers/flower_data/valid/24/image_06836.jpg
# /kaggle/input/flowers/flower_data/valid/24/image_06847.jpg
# /kaggle/input/flowers/flower_data/valid/24/image_06819.jpg
# /kaggle/input/flowers/flower_data/valid/24/image_06814.jpg
# /kaggle/input/flowers/flower_data/valid/73/image_00378.jpg
# /kaggle/input/flowers/flower_data/valid/73/image_00421.jpg
# /kaggle/input/flowers/flower_data/valid/73/image_00354.jpg
# /kaggle/input/flowers/flower_data/valid/73/image_00275.jpg
# /kaggle/input/flowers/flower_data/valid/73/image_00352.jpg
# /kaggle/input/flowers/flower_data/valid/73/image_00442.jpg
# /kaggle/input/flowers/flower_data/valid/73/image_00415.jpg
# /kaggle/input/flowers/flower_data/valid/73/image_00302.jpg
# /kaggle/input/flowers/flower_data/valid/73/image_00440.jpg
# /kaggle/input/flowers/flower_data/valid/73/image_00402.jpg
# /kaggle/input/flowers/flower_data/valid/73/image_00280.jpg
# /kaggle/input/flowers/flower_data/valid/73/image_00295.jpg
# /kaggle/input/flowers/flower_data/valid/73/image_00356.jpg
# /kaggle/input/flowers/flower_data/valid/73/image_00436.jpg
# /kaggle/input/flowers/flower_data/valid/73/image_00432.jpg
# /kaggle/input/flowers/flower_data/valid/73/image_00366.jpg
# /kaggle/input/flowers/flower_data/valid/73/image_00424.jpg
# /kaggle/input/flowers/flower_data/valid/73/image_00329.jpg
# /kaggle/input/flowers/flower_data/valid/73/image_00381.jpg
# /kaggle/input/flowers/flower_data/valid/93/image_06024.jpg
# ...
# /kaggle/input/flowers/flower_data/train/29/image_04140.jpg
# /kaggle/input/flowers/flower_data/train/29/image_04148.jpg
# /kaggle/input/flowers/flower_data/train/29/image_04089.jpg
# /kaggle/input/flowers/flower_data/train/29/image_04084.jpg
# /kaggle/input/flowers/flower_data/train/29/image_04138.jpg
# /kaggle/input/flowers/flower_data/train/29/image_04147.jpg
# /kaggle/input/flowers/flower_data/train/29/image_04098.jpg
# /kaggle/input/flowers/flower_data/train/29/image_04154.jpg
# /kaggle/input/flowers/flower_data/train/29/image_04117.jpg
# /kaggle/input/flowers/flower_data/train/29/image_04126.jpg
# /kaggle/input/flowers/flower_data/train/29/image_04086.jpg
# /kaggle/input/flowers/flower_data/train/29/image_04129.jpg
# /kaggle/input/flowers/flower_data/train/29/image_04135.jpg
# /kaggle/input/flowers/flower_data/train/29/image_04139.jpg
# /kaggle/input/flowers/flower_data/train/29/image_04105.jpg
# /kaggle/input/flowers/flower_data/train/29/image_04152.jpg
# /kaggle/input/flowers/flower_data/train/29/image_04131.jpg
# /kaggle/input/flowers/flower_data/train/29/image_04128.jpg
# /kaggle/input/flowers/flower_data/train/29/image_04081.jpg
# /kaggle/input/flowers/flower_data/train/29/image_04115.jpg
# /kaggle/input/flowers/flower_data/train/29/image_04102.jpg
# /kaggle/input/flowers/flower_data/train/29/image_04123.jpg
# /kaggle/input/flowers/flower_data/train/29/image_04082.jpg
# /kaggle/input/flowers/flower_data/train/29/image_04134.jpg
# /kaggle/input/flowers/flower_data/train/29/image_04119.jpg
# /kaggle/input/flowers/flower_data/train/29/image_04130.jpg
# /kaggle/input/flowers/flower_data/train/29/image_04122.jpg
# /kaggle/input/flowers/flower_data/train/29/image_04127.jpg
# /kaggle/input/flowers/flower_data/train/29/image_04085.jpg
# /kaggle/input/flowers/flower_data/train/29/image_04093.jpg
# /kaggle/input/flowers/flower_data/train/29/image_04109.jpg
# /kaggle/input/flowers/flower_data/train/29/image_04087.jpg
# /kaggle/input/flowers/flower_data/train/29/image_04092.jpg
# /kaggle/input/flowers/flower_data/train/29/image_04100.jpg
# /kaggle/input/flowers/flower_data/train/29/image_04096.jpg
# /kaggle/input/flowers/flower_data/train/29/image_04101.jpg
# /kaggle/input/flowers/flower_data/train/29/image_04153.jpg
# /kaggle/input/flowers/flower_data/train/29/image_04114.jpg
# /kaggle/input/flowers/flower_data/train/29/image_04111.jpg
# /kaggle/input/flowers/flower_data/train/29/image_04132.jpg
# /kaggle/input/flowers/flower_data/train/29/image_04133.jpg
# /kaggle/input/flowers/flower_data/train/29/image_04157.jpg
# /kaggle/input/flowers/flower_data/train/29/image_04149.jpg
# /kaggle/input/flowers/flower_data/train/29/image_04141.jpg
# /kaggle/input/flowers/flower_data/train/29/image_04107.jpg
# /kaggle/input/flowers/flower_data/train/29/image_04144.jpg
# /kaggle/input/flowers/flower_data/train/29/image_04150.jpg
# /kaggle/input/flowers/flower_data/train/29/image_04156.jpg
# /kaggle/input/flowers/flower_data/train/29/image_04094.jpg
# /kaggle/input/flowers/flower_data/train/29/image_04125.jpg
# /kaggle/input/flowers/flower_data/train/29/image_04091.jpg
# /kaggle/input/flowers/flower_data/train/29/image_04088.jpg
# /kaggle/input/flowers/flower_data/train/29/image_04158.jpg
# /kaggle/input/flowers/flower_data/train/29/image_04120.jpg
# /kaggle/input/flowers/flower_data/train/24/image_06833.jpg
# /kaggle/input/flowers/flower_data/train/24/image_08051.jpg
# /kaggle/input/flowers/flower_data/train/24/image_06827.jpg
# /kaggle/input/flowers/flower_data/train/24/image_06821.jpg
# /kaggle/input/flowers/flower_data/train/24/image_08050.jpg
# /kaggle/input/flowers/flower_data/train/24/image_06829.jpg
# /kaggle/input/flowers/flower_data/train/24/image_06840.jpg
# /kaggle/input/flowers/flower_data/train/24/image_06837.jpg
# /kaggle/input/flowers/flower_data/train/24/image_06817.jpg
# /kaggle/input/flowers/flower_data/train/24/image_08052.jpg
# /kaggle/input/flowers/flower_data/train/24/image_06838.jpg
# /kaggle/input/flowers/flower_data/train/24/image_06841.jpg
# /kaggle/input/flowers/flower_data/train/24/image_06845.jpg
# /kaggle/input/flowers/flower_data/train/24/image_08048.jpg
# /kaggle/input/flowers/flower_data/train/24/image_06835.jpg
# /kaggle/input/flowers/flower_data/train/24/image_06839.jpg
# /kaggle/input/flowers/flower_data/train/24/image_06816.jpg
# /kaggle/input/flowers/flower_data/train/24/image_06844.jpg
# /kaggle/input/flowers/flower_data/train/24/image_06831.jpg
# /kaggle/input/flowers/flower_data/train/24/image_06822.jpg
# /kaggle/input/flowers/flower_data/train/24/image_06826.jpg
# /kaggle/input/flowers/flower_data/train/24/image_06825.jpg
# /kaggle/input/flowers/flower_data/train/24/image_08053.jpg
# /kaggle/input/flowers/flower_data/train/24/image_06842.jpg
# /kaggle/input/flowers/flower_data/train/24/image_06843.jpg
# /kaggle/input/flowers/flower_data/train/24/image_06820.jpg
# /kaggle/input/flowers/flower_data/train/24/image_06848.jpg
# /kaggle/input/flowers/flower_data/train/24/image_06828.jpg
# /kaggle/input/flowers/flower_data/train/24/image_06823.jpg
# /kaggle/input/flowers/flower_data/train/24/image_06830.jpg
# /kaggle/input/flowers/flower_data/train/24/image_06832.jpg
# /kaggle/input/flowers/flower_data/train/24/image_08049.jpg
# /kaggle/input/flowers/flower_data/train/24/image_06824.jpg
# /kaggle/input/flowers/flower_data/train/24/image_06846.jpg
# /kaggle/input/flowers/flower_data/train/24/image_06834.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00433.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00342.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00405.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00372.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00410.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00264.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00423.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00403.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00368.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00414.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00348.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00259.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00399.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00425.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00444.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00407.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00312.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00314.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00256.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00311.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00340.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00404.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00431.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00278.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00406.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00357.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00434.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00385.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00323.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00438.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00254.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00316.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00292.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00384.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00343.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00364.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00331.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00411.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00379.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00420.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00265.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00273.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00308.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00428.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00412.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00398.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00286.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00285.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00313.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00267.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00371.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00290.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00418.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00360.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00341.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00322.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00429.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00383.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00396.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00390.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00344.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00262.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00363.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00297.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00417.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00301.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00374.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00338.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00304.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00375.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00377.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00332.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00310.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00370.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00306.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00326.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00392.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00416.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00333.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00289.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00287.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00299.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00298.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00367.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00339.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00388.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00269.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00359.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00261.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00271.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00346.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00325.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00355.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00293.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00257.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00413.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00397.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00391.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00373.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00395.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00351.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00376.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00263.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00309.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00327.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00315.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00441.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00328.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00321.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00279.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00252.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00361.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00427.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00276.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00296.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00305.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00336.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00274.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00318.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00272.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00268.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00380.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00439.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00430.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00443.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00281.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00307.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00266.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00283.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00437.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00419.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00358.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00422.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00334.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00347.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00386.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00435.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00255.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00393.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00382.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00408.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00253.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00270.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00350.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00300.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00317.jpg
# /kaggle/input/flowers/flower_data/train/73/image_00362.jpg
# /kaggle/input/flowers/flower_data/train/93/image_08112.jpg
# /kaggle/input/flowers/flower_data/train/93/image_06015.jpg
# /kaggle/input/flowers/flower_data/train/93/image_06012.jpg
# /kaggle/input/flowers/flower_data/train/93/image_06041.jpg
# /kaggle/input/flowers/flower_data/train/93/image_06039.jpg
# /kaggle/input/flowers/flower_data/train/93/image_08117.jpg
# /kaggle/input/flowers/flower_data/train/93/image_08115.jpg
# /kaggle/input/flowers/flower_data/train/93/image_06036.jpg
# /kaggle/input/flowers/flower_data/train/93/image_06027.jpg
# /kaggle/input/flowers/flower_data/train/93/image_06016.jpg
# /kaggle/input/flowers/flower_data/train/93/image_06034.jpg
# /kaggle/input/flowers/flower_data/train/93/image_06045.jpg
# /kaggle/input/flowers/flower_data/train/93/image_06020.jpg
# /kaggle/input/flowers/flower_data/train/93/image_08116.jpg
# /kaggle/input/flowers/flower_data/train/93/image_06030.jpg
# /kaggle/input/flowers/flower_data/train/93/image_06019.jpg
# /kaggle/input/flowers/flower_data/train/93/image_06025.jpg
# /kaggle/input/flowers/flower_data/train/93/image_08114.jpg
# /kaggle/input/flowers/flower_data/train/93/image_06028.jpg
# /kaggle/input/flowers/flower_data/train/93/image_06011.jpg
# /kaggle/input/flowers/flower_data/train/93/image_06043.jpg
# /kaggle/input/flowers/flower_data/train/93/image_06038.jpg
# /kaggle/input/flowers/flower_data/train/93/image_06047.jpg
# /kaggle/input/flowers/flower_data/train/93/image_06035.jpg
# /kaggle/input/flowers/flower_data/train/93/image_06029.jpg
# /kaggle/input/flowers/flower_data/train/93/image_06042.jpg
# /kaggle/input/flowers/flower_data/train/93/image_06013.jpg
# /kaggle/input/flowers/flower_data/train/93/image_06040.jpg
# /kaggle/input/flowers/flower_data/train/93/image_06046.jpg
# /kaggle/input/flowers/flower_data/train/93/image_06032.jpg
# /kaggle/input/flowers/flower_data/train/93/image_06026.jpg
# /kaggle/input/flowers/flower_data/train/93/image_06018.jpg
# /kaggle/input/flowers/flower_data/train/93/image_06022.jpg
# /kaggle/input/flowers/flower_data/train/93/image_06023.jpg
# /kaggle/input/cat-to-name/cat_to_name.json

# %%
# Before you proceed, update the PATH
import os
os.environ['PATH'] = f"{os.environ['PATH']}:/root/.local/bin"
os.environ['PATH'] = f"{os.environ['PATH']}:/opt/conda/lib/python3.6/site-packages"
# Restart the Kernel at this point.

# %%
# Do not execute the commands below unless you have restart the Kernel after updating the PATH. 
# !python -m pip install torch==1.0.0
# Out:
# ERROR: Could not find a version that satisfies the requirement torch==1.0.0 (from versions: 1.11.0, 1.12.0, 1.12.1, 1.13.0, 1.13.1, 2.0.0, 2.0.1, 2.1.0, 2.1.1, 2.1.2)
# ERROR: No matching distribution found for torch==1.0.0

# %%
# Check torch version and CUDA status if GPU is enabled.
import torch
print(torch.__version__)
print(torch.cuda.is_available()) # Should return True when GPU is enabled.
# Out:
# 2.0.0
# True

# %% [markdown]
# # Developing an AI application
#
# Going forward, AI algorithms will be incorporated into more and more everyday applications. For example, you might want to include an image classifier in a smart phone app. To do this, you'd use a deep learning model trained on hundreds of thousands of images as part of the overall application architecture. A large part of software development in the future will be using these types of models as common parts of applications.
#
# In this project, you'll train an image classifier to recognize different species of flowers. You can imagine using something like this in a phone app that tells you the name of the flower your camera is looking at. In practice you'd train this classifier, then export it for use in your application. We'll be using [this dataset](http://www.robots.ox.ac.uk/~vgg/data/flowers/102/index.html) of 102 flower categories, you can see a few examples below.
#
# <img src='assets/Flowers.png' width=500px>
#
# The project is broken down into multiple steps:
#
# * Load and preprocess the image dataset
# * Train the image classifier on your dataset
# * Use the trained classifier to predict image content
#
# We'll lead you through each part which you'll implement in Python.
#
# When you've completed this project, you'll have an application that can be trained on any set of labeled images. Here your network will be learning about flowers and end up as a command line application. But, what you do with your new skills depends on your imagination and effort in building a dataset. For example, imagine an app where you take a picture of a car, it tells you what the make and model is, then looks up information about it. Go build your own dataset and make something new.
#
# First up is importing the packages you'll need. It's good practice to keep all the imports at the beginning of your code. As you work through this notebook and find you need to import a package, make sure to add the import up here.

# %%
import signal

from contextlib import contextmanager

import requests


DELAY = INTERVAL = 4 * 60  # interval time in seconds
MIN_DELAY = MIN_INTERVAL = 2 * 60
KEEPALIVE_URL = "https://nebula.udacity.com/api/v1/remote/keep-alive"
TOKEN_URL = "http://metadata.google.internal/computeMetadata/v1/instance/attributes/keep_alive_token"
TOKEN_HEADERS = {"Metadata-Flavor":"Google"}


def _request_handler(headers):
    def _handler(signum, frame):
        requests.request("POST", KEEPALIVE_URL, headers=headers)
    return _handler


@contextmanager
def active_session(delay=DELAY, interval=INTERVAL):
    """
    Example:

    from workspace_utils import active session

    with active_session():
        # do long-running work here
    """
    token = requests.request("GET", TOKEN_URL, headers=TOKEN_HEADERS).text
    headers = {'Authorization': "STAR " + token}
    delay = max(delay, MIN_DELAY)
    interval = max(interval, MIN_INTERVAL)
    original_handler = signal.getsignal(signal.SIGALRM)
    try:
        signal.signal(signal.SIGALRM, _request_handler(headers))
        signal.setitimer(signal.ITIMER_REAL, delay, interval)
        yield
    finally:
        signal.signal(signal.SIGALRM, original_handler)
        signal.setitimer(signal.ITIMER_REAL, 0)


def keep_awake(iterable, delay=DELAY, interval=INTERVAL):
    """
    Example:

    from workspace_utils import keep_awake

    for i in keep_awake(range(5)):
        # do iteration with lots of work here
    """
    with active_session(delay, interval): yield from iterable

# %%
# Imports here

# %matplotlib inline 
# %config InlineBackend.figure_format = 'retina'
import numpy as np

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
from PIL import Image

import torch
from torch import nn
from torch import optim
from torchvision import models
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
from tabulate import tabulate
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# ## Load the data
#
# Here you'll use `torchvision` to load the data ([documentation](http://pytorch.org/docs/0.3.0/torchvision/index.html)). The data should be included alongside this notebook, otherwise you can [download it here](https://s3.amazonaws.com/content.udacity-data.com/nd089/flower_data.tar.gz).

# %% [markdown]
# If you do not find the `flowers/` dataset in the current directory, **/workspace/home/aipnd-project/**, you can download it using the following commands.
#
# ```bash
# !wget 'https://s3.amazonaws.com/content.udacity-data.com/nd089/flower_data.tar.gz'
# !unlink flowers
# !mkdir flowers && tar -xzf flower_data.tar.gz -C flowers
# ```

# %% [markdown]
# ## Data Description
# The dataset is split into three parts, training, validation, and testing. For the training, you'll want to apply transformations such as random scaling, cropping, and flipping. This will help the network generalize leading to better performance. You'll also need to make sure the input data is resized to 224x224 pixels as required by the pre-trained networks.
#
# The validation and testing sets are used to measure the model's performance on data it hasn't seen yet. For this you don't want any scaling or rotation transformations, but you'll need to resize then crop the images to the appropriate size.
#
# The pre-trained networks you'll use were trained on the ImageNet dataset where each color channel was normalized separately. For all three sets you'll need to normalize the means and standard deviations of the images to what the network expects. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`, calculated from the ImageNet images.  These values will shift each color channel to be centered at 0 and range from -1 to 1.

# %%
data_dir = '/kaggle/input/flowers/flower_data'  # Root directory

# Subdirectories
train_dir = os.path.join(data_dir, 'train')
valid_dir = os.path.join(data_dir, 'valid')
test_dir = os.path.join(data_dir, 'test')

# %%
# TODO: Define your transforms for the training, validation, and testing sets
train_data_transforms = transforms.Compose([
    transforms.RandomResizedCrop(224),
    transforms.RandomRotation(30),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
])

valid_data_transforms = transforms.Compose([
    transforms.Resize(225),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
])

test_data_transforms = transforms.Compose([
    transforms.Resize(225),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
])

# TODO: Load the datasets with ImageFolder
image_datasets = {
    'train': datasets.ImageFolder(train_dir, transform=train_data_transforms),
    'valid': datasets.ImageFolder(valid_dir, transform=valid_data_transforms),
    'test': datasets.ImageFolder(test_dir, transform=test_data_transforms),
}

# TODO: Using the image datasets and the trainforms, define the dataloaders
dataloaders = {
    'train': torch.utils.data.DataLoader(image_datasets['train'], batch_size=64, shuffle=True),
    'valid': torch.utils.data.DataLoader(image_datasets['valid'], batch_size=64),
    'test': torch.utils.data.DataLoader(image_datasets['test'], batch_size=64),
}

# %% [markdown]
# ### Label mapping
#
# You'll also need to load in a mapping from category label to category name. You can find this in the file `cat_to_name.json`. It's a JSON object which you can read in with the [`json` module](https://docs.python.org/2/library/json.html). This will give you a dictionary mapping the integer encoded categories to the actual names of the flowers.

# %%
import json

with open('/kaggle/input/cat-to-name/cat_to_name.json', 'r') as f:
    cat_to_name = json.load(f)

# %% [markdown]
# # Building and training the classifier
#
# Now that the data is ready, it's time to build and train the classifier. As usual, you should use one of the pretrained models from `torchvision.models` to get the image features. Build and train a new feed-forward classifier using those features.
#
# We're going to leave this part up to you. Refer to [the rubric](https://review.udacity.com/#!/rubrics/1663/view) for guidance on successfully completing this section. Things you'll need to do:
#
# * Load a [pre-trained network](http://pytorch.org/docs/master/torchvision/models.html) (If you need a starting point, the VGG networks work great and are straightforward to use)
# * Define a new, untrained feed-forward network as a classifier, using ReLU activations and dropout
# * Train the classifier layers using backpropagation using the pre-trained network to get the features
# * Track the loss and accuracy on the validation set to determine the best hyperparameters
#
# We've left a cell open for you below, but use as many as you need. Our advice is to break the problem up into smaller parts you can run separately. Check that each part is doing what you expect, then move on to the next. You'll likely find that as you work through each part, you'll need to go back and modify your previous code. This is totally normal!
#
# When training make sure you're updating only the weights of the feed-forward network. You should be able to get the validation accuracy above 70% if you build everything right. Make sure to try different hyperparameters (learning rate, units in the classifier, epochs, etc) to find the best model. Save those hyperparameters to use as default values in the next part of the project.
#
# One last important tip if you're using the workspace to run your code: To avoid having your workspace disconnect during the long-running tasks in this notebook, please read in the earlier page in this lesson called Intro to
# GPU Workspaces about Keeping Your Session Active. You'll want to include code from the workspace_utils.py module.
#
# ## Note for Workspace users:
# If your network is over 1 GB when saved as a checkpoint, there might be issues with saving backups in your workspace. Typically this happens with wide dense layers after the convolutional layers. If your saved checkpoint is larger than 1 GB (you can open a terminal and check with `ls -lh`), you should reduce the size of your hidden layers and train again.

# %%
# TODO: Build and train your network
device= torch.device("cuda" if torch.cuda.is_available() else "cpu")
# model= models.vgg16()

# for param in model.parameters():
#     param.requires_grad= False

    
# classifer= nn.Sequential(nn.Linear(1024, 512),
#                          nn.ReLU(),
#                          nn.Linear(512, 256),
#                          nn.ReLU(),
#                          nn.Linear(256, 102),
#                          nn.LogSoftmax(dim=1))
# criterion= nn.NLLLoss()

# optimizer= optim.Adam(model.classifier.parameters(), lr= 0.002)




#model.to(device);

# %%
model = models.vgg16_bn(pretrained=True)

# Freeze both feature and classifier parameters
for param in model.parameters():
    param.requires_grad = False

# Modify classifier
model.classifier = nn.Sequential(
    nn.Linear(25088, 4096),
    nn.ReLU(),
    nn.Dropout(0.5),
    nn.Linear(4096, 102),
    nn.LogSoftmax(dim=1)
)

criterion = nn.NLLLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Move the model to the appropriate device
# model.to(device)
# Out:
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_BN_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_BN_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/vgg16_bn-6c64b313.pth" to /root/.cache/torch/hub/checkpoints/vgg16_bn-6c64b313.pth
# 100%|██████████| 528M/528M [00:01<00:00, 294MB/s]

# %%
# Move model to GPU
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)

epochs = 10
steps = 0
running_loss = 0
print_every = 20
best_accuracy = 0.0

for epoch in range(epochs):
    model.train()
    for inputs, labels in dataloaders['train']:
        steps += 1
        inputs, labels = inputs.to(device), labels.to(device)

        optimizer.zero_grad()

        logps = model.forward(inputs)
        loss = criterion(logps, labels)
        loss.backward()
        optimizer.step()

        # Increment the running loss
        running_loss += loss.item()

    else:
    # Set the model to evaluation mode
        model.eval()
        valid_loss = 0
        accuracy = 0

        with torch.no_grad():
            for inputs, labels in dataloaders['valid']:
                inputs, labels = inputs.to(device), labels.to(device)
                logps = model.forward(inputs)
                batch_loss = criterion(logps, labels)

                valid_loss += batch_loss.item()

                # Calculating the accuracy of the model
                ps = torch.exp(logps)
                top_p, top_class = ps.topk(1, dim=1)
                equals = top_class == labels.view(*top_class.shape)
                accuracy += torch.mean(equals.type(torch.FloatTensor)).item()

        # Print the results in table format
#         print("Epoch: {}/{} | ".format(epoch+1, epochs))
#         print("Training Loss: {:.3f} | ".format(running_loss/len(dataloaders['train'])))
#         print("Validation Loss: {:.3f} | ".format(valid_loss/len(dataloaders['valid'])))
#         print("Validation Accuracy: {:.3f}".format(accuracy/len(dataloaders['valid'])))
#         # Store values in the table
        table = []
        table.append([epoch+1, epochs, running_loss/len(dataloaders['train']), valid_loss/len(dataloaders['valid']), accuracy/len(dataloaders['valid'])])

        # Print the table
        columns = ['Epoch', 'Total Epochs', 'Train Loss', 'Valid Loss', 'Accuracy']
        print(tabulate(table, columns, tablefmt='fancy_grid', floatfmt='8.3f'))

        

        model.train()
# Out:
# ╒═════════╤════════════════╤══════════════╤══════════════╤════════════╕
# │   Epoch │   Total Epochs │   Train Loss │   Valid Loss │   Accuracy │
# ╞═════════╪════════════════╪══════════════╪══════════════╪════════════╡
# │       1 │             10 │        2.946 │        1.223 │      0.657 │
# ╘═════════╧════════════════╧══════════════╧══════════════╧════════════╛
# ╒═════════╤════════════════╤══════════════╤══════════════╤════════════╕
# │   Epoch │   Total Epochs │   Train Loss │   Valid Loss │   Accuracy │
# ╞═════════╪════════════════╪══════════════╪══════════════╪════════════╡
# │       2 │             10 │        4.454 │        0.796 │      0.791 │
# ╘═════════╧════════════════╧══════════════╧══════════════╧════════════╛
# ╒═════════╤════════════════╤══════════════╤══════════════╤════════════╕
# │   Epoch │   Total Epochs │   Train Loss │   Valid Loss │   Accuracy │
# ╞═════════╪════════════════╪══════════════╪══════════════╪════════════╡
# │       3 │             10 │        5.729 │        0.607 │      0.825 │
# ╘═════════╧════════════════╧══════════════╧══════════════╧════════════╛
# ╒═════════╤════════════════╤══════════════╤══════════════╤════════════╕
# │   Epoch │   Total Epochs │   Train Loss │   Valid Loss │   Accuracy │
# ╞═════════╪════════════════╪══════════════╪══════════════╪════════════╡
# │       4 │             10 │        6.895 │        0.520 │      0.849 │
# ╘═════════╧════════════════╧══════════════╧══════════════╧════════════╛
# ╒═════════╤════════════════╤══════════════╤══════════════╤════════════╕
# │   Epoch │   Total Epochs │   Train Loss │   Valid Loss │   Accuracy │
# ╞═════════╪════════════════╪══════════════╪══════════════╪════════════╡
# │       5 │             10 │        7.966 │        0.534 │      0.841 │
# ╘═════════╧════════════════╧══════════════╧══════════════╧════════════╛
# ╒═════════╤════════════════╤══════════════╤══════════════╤════════════╕
# │   Epoch │   Total Epochs │   Train Loss │   Valid Loss │   Accuracy │
# ╞═════════╪════════════════╪══════════════╪══════════════╪════════════╡
# │       6 │             10 │        9.016 │        0.462 │      0.864 │
# ╘═════════╧════════════════╧══════════════╧══════════════╧════════════╛
# ╒═════════╤════════════════╤══════════════╤══════════════╤════════════╕
# │   Epoch │   Total Epochs │   Train Loss │   Valid Loss │   Accuracy │
# ╞═════════╪════════════════╪══════════════╪══════════════╪════════════╡
# │       7 │             10 │       10.051 │        0.476 │      0.868 │
# ╘═════════╧════════════════╧══════════════╧══════════════╧════════════╛
# ╒═════════╤════════════════╤══════════════╤══════════════╤════════════╕
# │   Epoch │   Total Epochs │   Train Loss │   Valid Loss │   Accuracy │
# ╞═════════╪════════════════╪══════════════╪══════════════╪════════════╡
# │       8 │             10 │       11.026 │        0.477 │      0.866 │
# ╘═════════╧════════════════╧══════════════╧══════════════╧════════════╛
# ╒═════════╤════════════════╤══════════════╤══════════════╤════════════╕
# │   Epoch │   Total Epochs │   Train Loss │   Valid Loss │   Accuracy │
# ╞═════════╪════════════════╪══════════════╪══════════════╪════════════╡
# │       9 │             10 │       12.016 │        0.486 │      0.862 │
# ╘═════════╧════════════════╧══════════════╧══════════════╧════════════╛
# ╒═════════╤════════════════╤══════════════╤══════════════╤════════════╕
# │   Epoch │   Total Epochs │   Train Loss │   Valid Loss │   Accuracy │
# ╞═════════╪════════════════╪══════════════╪══════════════╪════════════╡
# │      10 │             10 │       13.024 │        0.462 │      0.875 │
# ╘═════════╧════════════════╧══════════════╧══════════════╧════════════╛

# %% [markdown]
# ## Testing your network
#
# It's good practice to test your trained network on test data, images the network has never seen either in training or validation. This will give you a good estimate for the model's performance on completely new images. Run the test images through the network and measure the accuracy, the same way you did validation. You should be able to reach around 70% accuracy on the test set if the model has been trained well.

# %%
# TODO: Do validation on the test set
# Set the model to evaluation mode
model.eval()

# Variables to store test loss and accuracy
test_loss = 0
accuracy = 0

# Iterate over the test dataset
with torch.no_grad():
    for inputs, labels in dataloaders['test']:
        inputs, labels = inputs.to(device), labels.to(device)

        # Forward pass
        logps = model.forward(inputs)
        batch_loss = criterion(logps, labels)

        # Increment test loss
        test_loss += batch_loss.item()

        # Calculate accuracy
        ps = torch.exp(logps)
        top_p, top_class = ps.topk(1, dim=1)
        equals = top_class == labels.view(*top_class.shape)
        accuracy += torch.mean(equals.type(torch.FloatTensor)).item()

# Calculate average test loss and accuracy
average_test_loss = test_loss / len(dataloaders['test'])
average_accuracy = accuracy / len(dataloaders['test'])

# Print the results
print(f"Test loss: {average_test_loss:.3f}")
print(f"Test accuracy: {average_accuracy:.3f}")
# Out:
# Test loss: 0.523
# Test accuracy: 0.875

# %% [markdown]
# ## Save the checkpoint
#
# Now that your network is trained, save the model so you can load it later for making predictions. You probably want to save other things such as the mapping of classes to indices which you get from one of the image datasets: `image_datasets['train'].class_to_idx`. You can attach this to the model as an attribute which makes inference easier later on.
#
# ```model.class_to_idx = image_datasets['train'].class_to_idx```
#
# Remember that you'll want to completely rebuild the model later so you can use it for inference. Make sure to include any information you need in the checkpoint. If you want to load the model and keep training, you'll want to save the number of epochs as well as the optimizer state, `optimizer.state_dict`. You'll likely want to use this trained model in the next part of the project, so best to save it now.

# %%
# TODO: Save the checkpoint 

model.class_to_idx= image_datasets['train'].class_to_idx

checkpoint= {'input_size': 25088,
            'output_size': 102,
            'arch': 'vgg16',
            'classifier': model.classifier,
            'state_dict': model.state_dict(),
            'optimizer': optimizer.state_dict(),
            'class_to_idx': model.class_to_idx}

torch.save(checkpoint, 'checkpoint.pth')

# %% [markdown]
# ## Loading the checkpoint
#
# At this point it's good to write a function that can load a checkpoint and rebuild the model. That way you can come back to this project and keep working on it without having to retrain the network.

# %%
# TODO: Write a function that loads a checkpoint and rebuilds the model

def load_checkpoint(filepath):
    if torch.cuda.is_available():
        map_location=lambda storage, loc: storage.cuda()
    else:
        map_location='cpu'
    checkpoint= torch.load(filepath, map_location=map_location)
    
    #rebuild the model
    model= models.vgg16(pretrained=True)
    model.classifier= checkpoint['classifier']
    model.load_state_dict(checkpoint['state_dict'])
    model.class_to_idx= checkpoint['class_to_idx']
    
    return model

# %% [markdown]
# # Inference for classification
#
# Now you'll write a function to use a trained network for inference. That is, you'll pass an image into the network and predict the class of the flower in the image. Write a function called `predict` that takes an image and a model, then returns the top $K$ most likely classes along with the probabilities. It should look like
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```
#
# First you'll need to handle processing the input image such that it can be used in your network.
#
# ## Image Preprocessing
#
# You'll want to use `PIL` to load the image ([documentation](https://pillow.readthedocs.io/en/latest/reference/Image.html)). It's best to write a function that preprocesses the image so it can be used as input for the model. This function should process the images in the same manner used for training.
#
# First, resize the images where the shortest side is 256 pixels, keeping the aspect ratio. This can be done with the [`thumbnail`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) or [`resize`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) methods. Then you'll need to crop out the center 224x224 portion of the image.
#
# Color channels of images are typically encoded as integers 0-255, but the model expected floats 0-1. You'll need to convert the values. It's easiest with a Numpy array, which you can get from a PIL image like so `np_image = np.array(pil_image)`.
#
# As before, the network expects the images to be normalized in a specific way. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`. You'll want to subtract the means from each color channel, then divide by the standard deviation.
#
# And finally, PyTorch expects the color channel to be the first dimension but it's the third dimension in the PIL image and Numpy array. You can reorder dimensions using [`ndarray.transpose`](https://docs.scipy.org/doc/numpy-1.13.0/reference/generated/numpy.ndarray.transpose.html). The color channel needs to be first and retain the order of the other two dimensions.

# %%
def process_image(image_path):
    '''
    Scales, crops, and normalizes a PIL image for a PyTorch model,
    returns an Numpy array
    '''
    # Open the image
    img = Image.open(image_path)
    
    # Define the transformations
    preprocess = transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    ])
    
    # Apply the transformations
    img_tensor = preprocess(img)
    
    # Convert to NumPy array
    img_numpy = img_tensor.numpy()
    
    return img_numpy

# %% [markdown]
# To check your work, the function below converts a PyTorch tensor and displays it in the notebook. If your `process_image` function works, running the output through this function should return the original image (except for the cropped out portions).

# %%
def imshow(image, ax=None, title=None):
    """Imshow for Tensor or NumPy array."""
    if ax is None:
        fig, ax = plt.subplots()
    
    # Check if the image is a PyTorch tensor and convert it to a NumPy array
    if isinstance(image, torch.Tensor):
        image = image.numpy().transpose((1, 2, 0))
    else:
        image = image.transpose((1, 2, 0))
    
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    image = std * image + mean
    image = np.clip(image, 0, 1)
    
    ax.imshow(image)
    
    if title:
        ax.set_title(title)
    
    return ax

# %%
imshow(process_image('/kaggle/input/flowers/flower_data/train/75/image_02185.jpg'))
# Out:
# <Axes: >

# %% [markdown]
# ## Class Prediction
#
# Once you can get images in the correct format, it's time to write a function for making predictions with your model. A common practice is to predict the top 5 or so (usually called top-$K$) most probable classes. You'll want to calculate the class probabilities then find the $K$ largest values.
#
# To get the top $K$ largest values in a tensor use [`x.topk(k)`](http://pytorch.org/docs/master/torch.html#torch.topk). This method returns both the highest `k` probabilities and the indices of those probabilities corresponding to the classes. You need to convert from these indices to the actual class labels using `class_to_idx` which hopefully you added to the model or from an `ImageFolder` you used to load the data ([see here](#Save-the-checkpoint)). Make sure to invert the dictionary so you get a mapping from index to class as well.
#
# Again, this method should take a path to an image and a model checkpoint, then return the probabilities and classes.
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```

# %%
def predict(image_path, model, topk=5):
    ''' Predict the class (or classes) of an image using a trained deep learning model.
    '''
    # Load the image
    img = process_image(image_path)
    
    # Convert NumPy array to PyTorch tensor
    img = torch.from_numpy(img)
    
    # Add a batch dimension to the input image
    img = img.unsqueeze(0)
    
    # Move the model to the device (CPU or GPU)
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model.to(device)
    
    # Set the model to evaluation mode
    model.eval()
    
    # Move the image to the device
    img = img.to(device)
    
    # Perform the forward pass
    with torch.no_grad():
        output = model(img)
    
    # Calculate the probabilities and classes
    probabilities = torch.nn.functional.softmax(output[0], dim=0)
    top_probabilities, top_indices = torch.topk(probabilities, topk)
    
    # Convert indices to class labels using class_to_idx
    idx_to_class = {v: k for k, v in model.class_to_idx.items()}
    top_classes = [idx_to_class[idx.item()] for idx in top_indices]
    
    return top_probabilities.cpu().numpy(), top_classes

# %%
probs, classes = predict('/kaggle/input/flowers/flower_data/train/75/image_02185.jpg', model)
print("Probabilities")
print(probs)
print("Predicted Classes:")
print(classes)
# Out:
# Probabilities
# [9.9999952e-01 4.3257234e-07 9.9630726e-10 9.8340491e-10 8.9077890e-10]
# Predicted Classes:
# ['75', '76', '20', '82', '19']

# %% [markdown]
# ## Sanity Checking
#
# Now that you can use a trained model for predictions, check to make sure it makes sense. Even if the testing accuracy is high, it's always good to check that there aren't obvious bugs. Use `matplotlib` to plot the probabilities for the top 5 classes as a bar graph, along with the input image. It should look like this:
#
# <img src='assets/inference_example.png' width=300px>
#
# You can convert from the class integer encoding to actual flower names with the `cat_to_name.json` file (should have been loaded earlier in the notebook). To show a PyTorch tensor as an image, use the `imshow` function defined above.

# %%
def plot_prediction(image_path, model, cat_to_name):
    # Make prediction
    probs, classes = predict(image_path, model)

    # Load and process the image
    img = Image.open(image_path)

    # Display the image along with the top 5 classes
    flower_classes = [cat_to_name[j] for j in classes]

    plt.figure(figsize=[5, 10])

    # Display the image
    plt.figure(figsize = [5, 10])
    ax1 = plt.subplot(2, 1, 1)
    ax1.set_axis_off()
    ax1.set_title(flower_classes[0])
    ax1.imshow(img)

    # Plot the probabilities as a bar graph
    ax2 = plt.subplot(2, 1, 2)
    y_pos = np.arange(5)
    ax2.set_yticks(y_pos)
    ax2.set_yticklabels(flower_classes)
    ax2.invert_yaxis()
    ax2.set_xlabel('Probability')
    plt.barh(y_pos, probs)

    plt.show()

# %%
image_path = '/kaggle/input/flowers/flower_data/test/16/image_06670.jpg'
image_path1 = '/kaggle/input/flowers/flower_data/test/17/image_03864.jpg'

plot_prediction(image_path, model, cat_to_name)
plot_prediction(image_path1, model, cat_to_name)

# %% [markdown]
# ## Reminder for Workspace users
# If your network becomes very large when saved as a checkpoint, there might be issues with saving backups in your workspace. You should reduce the size of your hidden layers and train again.
#
# We strongly encourage you to delete these large interim files and directories before navigating to another page or closing the browser tab.
